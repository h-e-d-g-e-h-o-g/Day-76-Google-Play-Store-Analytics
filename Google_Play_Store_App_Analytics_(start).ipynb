# %% [markdown]
# <a href="https://colab.research.google.com/github/h-e-d-g-e-h-o-g/Day-76-Google-Play-Store-Analytics/blob/main/Google_Play_Store_App_Analytics_(start).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                       App          Category  Rating  Reviews  \
# 9744                  easyJet: Travel App  TRAVEL_AND_LOCAL    4.40   134895
# 4831  Scanning body and undressing people            FAMILY    3.40     1012
# 6663           Display Phone Screen On TV             TOOLS    3.60     9895
# 7068                         video player     VIDEO_PLAYERS    4.40    26421
# 9630           Pregnant Emergency Surgery            FAMILY    3.80   127229
#
#       Size_MBs    Installs  Type Price Content_Rating  \
# 9744     50.00  10,000,000  Free     0       Everyone
# 4831     12.00     100,000  Free     0           Teen
# 6663      2.70   1,000,000  Free     0       Everyone
# 7068      4.65   1,000,000  Free     0       Everyone
# 9630     34.00  10,000,000  Free     0       Everyone
#
#                        Genres       Last_Updated Android_Ver
# 9744           Travel & Local       July 1, 2018  4.2 and up
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(columns=["Last_Updated", "Android_Ver"], axis=1, inplace=True)

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
duplicated_rows.head()
# Out:
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating

# %%
df_apps_clean = df_apps_clean[df_apps_clean["App"] == 'Instagram']
df_apps_clean
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=["App", "Type", "Price"])
df_apps_clean[df_apps_clean["App"] == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %%
df_apps_data_clean = df_apps.drop_duplicates(subset=["App", "Type", "Price"])
df_apps_data_clean.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_data_clean.sort_values('Rating', ascending=False).head()
# Out:
#                       App     Category  Rating  Reviews  Size_MBs Installs  \
# 21    KBA-EZ Health Guide      MEDICAL    5.00        4     25.00        1
# 1230         Sway Medical      MEDICAL    5.00        3     22.00      100
# 1227    AJ Men's Grooming    LIFESTYLE    5.00        2     22.00      100
# 1224       FK Dedinje BGD       SPORTS    5.00       36      2.60      100
# 1223      CB VIDEO VISION  PHOTOGRAPHY    5.00       13      2.60      100
#
#       Type Price Content_Rating       Genres
# 21    Free     0       Everyone      Medical
# 1230  Free     0       Everyone      Medical
# 1227  Free     0       Everyone    Lifestyle
# 1224  Free     0       Everyone       Sports
# 1223  Free     0       Everyone  Photography

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_data_clean.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                 App            Category  Rating  Reviews  \
# 3144                     Vi Trainer  HEALTH_AND_FITNESS    3.60      124
# 9944   Gangster Town: Vice District              FAMILY    4.30    65146
# 7926                      Post Bank             FINANCE    4.50    60449
# 7927    The Walking Dead: Our World                GAME    4.00    22435
# 7928  Stickman Legends: Shadow Wars                GAME    4.40    38419
#
#       Size_MBs    Installs  Type  Price Content_Rating            Genres
# 3144    100.00       5,000  Free      0       Everyone  Health & Fitness
# 9944    100.00  10,000,000  Free      0     Mature 17+        Simulation
# 7926    100.00   1,000,000  Free      0       Everyone           Finance
# 7927    100.00   1,000,000  Free      0           Teen            Action
# 7928    100.00   1,000,000  Paid  $0.99   Everyone 10+            Action

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_data_clean.sort_values('Reviews', ascending=False).head(5)
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 10805  78158306      5.30  1000000000  Free   0.00           Teen
# 10785  69119316      3.50  1000000000  Free   0.00       Everyone
# 10806  66577313      5.30  1000000000  Free   0.00           Teen
# 10784  56642847      3.50  1000000000  Free   0.00       Everyone
# 10650  44891723     98.00   100000000  Free   0.00   Everyone 10+
#
#               Genres  Revenue_Estimate
# 10805         Social              0.00
# 10785  Communication              0.00
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_data_clean["Content_Rating"].value_counts()
ratings
# Out:
# Everyone           7906
# Teen               1036
# Mature 17+          393
# Everyone 10+        322
# Adults only 18+       3
# Unrated               2
# Name: Content_Rating, dtype: int64

# %%
fig = px.pie(values=ratings.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(values=ratings.values, title="Content Rating", names=ratings.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(values=ratings.values, title="Content Rating", names=ratings.index)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_data_clean["Installs"].describe()
# Out:
# count          9662
# unique           20
# top       1,000,000
# freq           1419
# Name: Installs, dtype: object

# %%
df_apps_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9662 entries, 0 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9662 non-null   object
#  1   Category        9662 non-null   object
#  2   Rating          8198 non-null   float64
#  3   Reviews         9662 non-null   int64
#  4   Size_MBs        9662 non-null   float64
#  5   Installs        9662 non-null   object
#  6   Type            9661 non-null   object
#  7   Price           9662 non-null   object
#  8   Content_Rating  9662 non-null   object
#  9   Genres          9662 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 830.3+ KB

# %%
apps_data = df_apps_data_clean[["Installs", "App"]].groupby("Installs").count()
apps_data
# Out:
#                 App
# Installs
# 0                15
# 1                67
# 1,000           890
# 1,000,000      1419
# 1,000,000,000    20
# 10              385
# 10,000         1032
# 10,000,000      933
# 100             710
# 100,000        1114
# 100,000,000     189
# 5                82
# 5,000           468
# 5,000,000       606
# 50              204
# 50,000          469
# 50,000,000      202
# 500             328
# 500,000         505
# 500,000,000      24

# %%
df_apps_data_clean.Installs = df_apps_data_clean.Installs.astype(str).str.replace(",", "")
df_apps_data_clean.Installs = pd.to_numeric(df_apps_data_clean.Installs)
df_apps_data_clean[["Installs", "App"]].groupby("Installs").count()
# Out:
# <ipython-input-25-dfad0b4a06f5>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-25-dfad0b4a06f5>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              App
# Installs
# 0             15
# 1             67
# 5             82
# 10           385
# 50           204
# 100          710
# 500          328
# 1000         890
# 5000         468
# 10000       1032
# 50000        469
# 100000      1114
# 500000       505
# 1000000     1419
# 5000000      606
# ...

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_data_clean.Price = df_apps_data_clean["Price"].astype("str").str.replace("$", "")
df_apps_data_clean.Price = pd.to_numeric(df_apps_data_clean.Price)
apps_price_data = df_apps_data_clean.sort_values('Price',ascending=False)[["App", "Price", "Installs"]]
# Out:
# <ipython-input-26-0b162b2115ef>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-26-0b162b2115ef>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-26-0b162b2115ef>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
apps_price_data["Price"].head(20)
# Out:
# 3946   400.00
# 2394   399.99
# 2775   399.99
# 1331   399.99
# 3145   399.99
# 3221   399.99
# 4606   399.99
# 1946   399.99
# 3114   399.99
# 5765   399.99
# 2461   399.99
# 3554   399.99
# 14     399.99
# 13     394.99
# 3897   389.99
# 2193   379.99
# 3856   299.99
# 11     200.00
# 8      154.99
# 58     109.99
# Name: Price, dtype: float64

# %% [markdown]
# ### The most expensive apps sub $250

# %%
# df_apps_data_clean.drop(columns=["Revenue_Estimate"], axis=1, inplace=True)
df_apps_data_clean['Revenue_Estimate'] = df_apps_data_clean.Installs.mul(df_apps_data_clean.Price)
df_apps_data_clean['Revenue_Estimate'].fillna(0, inplace=True)
apps_under_250 = apps_price_data[apps_price_data["Price"] < 250]
apps_under_250
# Out:
#                                     App  Price    Installs
# 11                         EP Cook Book 200.00           0
# 8                         cronometra-br 154.99           0
# 58              BP Fitness Lead Scanner 109.99           1
# 280                             Lean EQ  89.99          10
# 2281          Vargo Anesthesia Mega App  79.99        1000
# ...                                 ...    ...         ...
# 3566   Theme for Samsung Galaxy Note FE   0.00       10000
# 3565              Mirk V Launcher Theme   0.00       10000
# 3564            Theme for Iphone X Plus   0.00       10000
# 3563      AL.com: Alabama Football News   0.00       10000
# 10835                    Subway Surfers   0.00  1000000000
#
# [9645 rows x 3 columns]

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
apps_under_250.head(20)
# Out:
#                                                    App  Price  Installs
# 11                                        EP Cook Book 200.00         0
# 8                                        cronometra-br 154.99         0
# 58                             BP Fitness Lead Scanner 109.99         1
# 280                                            Lean EQ  89.99        10
# 2281                         Vargo Anesthesia Mega App  79.99      1000
# 1886                         Language Therapy: Aphasia  74.99      1000
# 494                          Dr.Dice - Sic bo analyzer  46.99        10
# 86                       Norwegian For Kids & Babies F  39.99         5
# 1407                                      LTC AS Legal  39.99       100
# 2629                                  I am Rich Person  37.99      1000
# 2481                           A Manual of Acupuncture  33.99      1000
# 9                                          Eu sou Rico  30.99         0
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_data_clean["Category"].nunique()
# Out:
# 33

# %%
apps_under_10 = df_apps_data_clean["Category"].value_counts()[:10]
apps_under_10
# Out:
# FAMILY             1834
# GAME                957
# TOOLS               828
# BUSINESS            419
# MEDICAL             397
# PERSONALIZATION     376
# PRODUCTIVITY        374
# LIFESTYLE           370
# FINANCE             345
# SPORTS              325
# Name: Category, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
px.bar(x=apps_under_10.index, y=apps_under_10.values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
apps_installation = df_apps_data_clean.groupby("Category").agg({"Installs": pd.Series.sum})
apps_installation.sort_values("Installs", ascending=False, inplace=True)

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
h_bar = px.bar(x=apps_installation.Installs, y=apps_installation.index, orientation='h', title="Category Popularity")
h_bar.update_layout(xaxis_title="Number of Downloads", yaxis_title="Category")
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
apps_in_category = df_apps_data_clean.groupby("Category").agg({"App": pd.Series.count})
category_installed = df_apps_data_clean.groupby("Category").agg({"Installs": pd.Series.sum})
apps_category_df = pd.DataFrame(apps_in_category)
installed_category_df = pd.DataFrame(category_installed)
installed_category_df
app_df = pd.merge(apps_category_df, installed_category_df, on="Category")
app_df.sort_values("Installs", ascending=False, inplace=True)
fig = px.scatter(x=app_df["App"],
                 y=app_df["Installs"],
                 size=app_df["App"],
                 color=app_df["Installs"],
                 hover_name=app_df.index,
                 title='Category Concentration'
                 )
fig.update_layout(xaxis_title="Number of Apps(Lower=More Concentrated)", yaxis_title="Installs", yaxis=dict(type='log'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_data_clean.Genres.value_counts().sort_values().head(5)
stack = df_apps_data_clean.Genres.str.split(";", expand=True).stack()
num_genres = stack.value_counts()
len(num_genres)
# Out:
# 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
fig = px.bar(x=num_genres.index[:15],
             y=num_genres.values[:15],
             title="Top Genres",
             hover_name=num_genres.index[:15],
             color=num_genres.values[:15],
             color_continuous_scale="Agsunset")

fig.update_layout(xaxis_title="Genres",
                  yaxis_title="Number of Apps",
                  coloraxis_showscale=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_data_clean.Type.value_counts()
df_free_vs_paid = df_apps_data_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head(2)
# Out:
#          Category  Type  App
# 0  ART_AND_DESIGN  Free   61
# 1  ART_AND_DESIGN  Paid    3

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
fig = px.bar(x=df_free_vs_paid["Category"],
             y=df_free_vs_paid["App"],
             color=df_free_vs_paid["Type"],
             title="Free vs Paid Apps by Category",
             barmode='group'
             )
fig.update_layout(xaxis_title="Category",
                  yaxis_title="Number of Apps",
                  xaxis={'categoryorder':'total descending'},
                  yaxis=dict(type='log'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
df_apps_installed = df_apps_data_clean.Installs.astype("str").str.replace(",", "")
df_apps_data_clean.Installs = pd.to_numeric(df_apps_installed)
box = px.box(x=df_apps_data_clean["Type"],
             y=df_apps_data_clean["Installs"],
             color=df_apps_data_clean["Type"],
             notched=True,
             points="all",
             title="How Many Downloads are Paid Apps Giving Up?"
             )
box.update_layout(xaxis_title="Type",
                  yaxis_title="Installs",
                  yaxis=dict(type='log'))
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_data_clean[df_apps_data_clean['Type'] == 'Paid']
box = px.box(df_paid_apps,
             x='Category',
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))


box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
box = px.box(df_paid_apps,
             x='Category',
             y='Price',
             title='Price per Category')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
